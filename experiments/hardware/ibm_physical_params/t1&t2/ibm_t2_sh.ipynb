# %%
from qiskit import QuantumCircuit, transpile
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2
from qiskit.circuit import Delay

import sys
import os

sys.path.append(os.path.abspath("..\\..\\..\\.."))
from metrics.IBM.get_calibration_data import get_calibration_data, get_best_qubits

# %%
def load_circuit(delay, qb_len=1):
    qc = QuantumCircuit(qb_len, qb_len)

    
    qc.h(range(qb_len))
    qc.s(range(qb_len)) # estado inicial +i
    for i in range(qb_len):
        qc.append(Delay(delay), [i])
    qc.sdg(range(qb_len))
    qc.h(range(qb_len))
    qc.measure(range(qb_len), range(qb_len))

    return qc

qc = load_circuit(1000, 10)
qc.draw('mpl')

# %%
ibm_token = ""
service = QiskitRuntimeService(channel="ibm_quantum", token=ibm_token)
backend = service.backend("ibm_brisbane")
data_csv = 'ibm_brisbane_calibrations_2024-12-30T22_59_28Z.csv'

# %%
best_T2_qubits = get_best_qubits(data_csv, lambda x: x.T2, 10)
print(*[f"{q.Qubit}, T2={round(q.T2, 3)}" for q in best_T2_qubits], sep= '\n')
# Out:
# 36, T2=326.491
# 2, T2=310.758
# 116, T2=302.739
# 111, T2=290.591
# 110, T2=286.375
# 51, T2=278.685
# 17, T2=274.745
# 125, T2=257.986
# 20, T2=252.303
# 11, T2=251.274

# %%
isa_circuit = transpile(qc, backend, scheduling_method="asap", optimization_level=3, initial_layout=[q.Qubit for q in best_T2_qubits])
print(f"Circuit Depth: {qc.depth()}")
print(f"Transpiled Circuit Depth: {isa_circuit.depth()}")
# isa_circuit.draw(output='mpl')
# Out:
# Circuit Depth: 6
# Transpiled Circuit Depth: 7

# %%
dt = backend.configuration().dt * 10**9
print(f'dt = {round(dt, 3)} ns')
# Out:
# dt = 0.5 ns

# %%
t_array = [t*5_000 for t in range(0, 81)]
print([round(t*dt * 10**(-3),2) for t in t_array])
# Out:
# [0.0, 2.5, 5.0, 7.5, 10.0, 12.5, 15.0, 17.5, 20.0, 22.5, 25.0, 27.5, 30.0, 32.5, 35.0, 37.5, 40.0, 42.5, 45.0, 47.5, 50.0, 52.5, 55.0, 57.5, 60.0, 62.5, 65.0, 67.5, 70.0, 72.5, 75.0, 77.5, 80.0, 82.5, 85.0, 87.5, 90.0, 92.5, 95.0, 97.5, 100.0, 102.5, 105.0, 107.5, 110.0, 112.5, 115.0, 117.5, 120.0, 122.5, 125.0, 127.5, 130.0, 132.5, 135.0, 137.5, 140.0, 142.5, 145.0, 147.5, 150.0, 152.5, 155.0, 157.5, 160.0, 162.5, 165.0, 167.5, 170.0, 172.5, 175.0, 177.5, 180.0, 182.5, 185.0, 187.5, 190.0, 192.5, 195.0, 197.5, 200.0]

# %%
circuits = []

for t in t_array:

    qc = load_circuit(t, qb_len=10)

    isa_circuit = transpile(qc, backend, scheduling_method="asap", optimization_level=3, initial_layout=[q.Qubit for q in best_T2_qubits])
    circuits.append(isa_circuit)

    print(f"Circuit Depth: {circuits[-1].depth()}")
    print(f"Delay Duration: {round(t*dt * 10**(-3), 3)} μs")
    print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
    # c.draw(output='mpl')
# Out:
# Circuit Depth: 6
# Delay Duration: 0.0 μs
# Total Duration: 1.42 μs
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
# Circuit Depth: 7
# Delay Duration:
42 μs
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
# Circuit Depth: 7
# Delay Duration: 197.5 μs
# Total Duration: 198.92 μs
#
# Circuit Depth: 7
# Delay Duration: 200.0 μs
# Total Duration: 201.42 μs
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")
# C:\Users\marzu\AppData\Local\Temp\ipykernel_15236\2406943209.py:12: DeprecationWarning: The property ``qiskit.circuit.quantumcircuit.QuantumCircuit.duration`` is deprecated as of qiskit 1.3.0. It will be removed in Qiskit 2.0.0.
#   print(f"Total Duration: {round(circuits[-1].duration*dt * 10**(-3), 3)} μs\n")

# %%
def get_layout(circuit, qb_len=1):
    layout = circuit._layout.initial_layout.get_virtual_bits()
    print(layout)
    keys = [layout[i] for i in layout]
    return keys[:qb_len]

# for c in circuits:
#     get_layout(c, qb_len=10)

data_qubits, data_edges = get_calibration_data(data_csv)

layout = get_layout(circuits[0], qb_len=10)

print(layout)
# Out:
# {Qubit(QuantumRegister(10, 'q'), 0): 36, Qubit(QuantumRegister(10, 'q'), 1): 2, Qubit(QuantumRegister(10, 'q'), 2): 116, Qubit(QuantumRegister(10, 'q'), 3): 111, Qubit(QuantumRegister(10, 'q'), 4): 110, Qubit(QuantumRegister(10, 'q'), 5): 51, Qubit(QuantumRegister(10, 'q'), 6): 17, Qubit(QuantumRegister(10, 'q'), 7): 125, Qubit(QuantumRegister(10, 'q'), 8): 20, Qubit(QuantumRegister(10, 'q'), 9): 11, Qubit(QuantumRegister(117, 'ancilla'), 0): 0, Qubit(QuantumRegister(117, 'ancilla'), 1): 1, Qubit(QuantumRegister(117, 'ancilla'), 2): 3, Qubit(QuantumRegister(117, 'ancilla'), 3): 4, Qubit(QuantumRegister(117, 'ancilla'), 4): 5, Qubit(QuantumRegister(117, 'ancilla'), 5): 6, Qubit(QuantumRegister(117, 'ancilla'), 6): 7, Qubit(QuantumRegister(117, 'ancilla'), 7): 8, Qubit(QuantumRegister(117, 'ancilla'), 8): 9, Qubit(QuantumRegister(117, 'ancilla'), 9): 10, Qubit(QuantumRegister(117, 'ancilla'), 10): 12, Qubit(QuantumRegister(117, 'ancilla'), 11): 13, Qubit(QuantumRegister(117, 'ancilla'), 12): 14, Qubit(QuantumRegister(117, 'ancilla'), 13): 15, Qubit(QuantumRegister(117, 'ancilla'), 14): 16, Qubit(QuantumRegister(117, 'ancilla'), 15): 18, Qubit(QuantumRegister(117, 'ancilla'), 16): 19, Qubit(QuantumRegister(117, 'ancilla'), 17): 21, Qubit(QuantumRegister(117, 'ancilla'), 18): 22, Qubit(QuantumRegister(117, 'ancilla'), 19): 23, Qubit(QuantumRegister(117, 'ancilla'), 20): 24, Qubit(QuantumRegister(117, 'ancilla'), 21): 25, Qubit(QuantumRegister(117, 'ancilla'), 22): 26, Qubit(QuantumRegister(117, 'ancilla'), 23): 27, Qubit(QuantumRegister(117, 'ancilla'), 24): 28, Qubit(QuantumRegister(117, 'ancilla'), 25): 29, Qubit(QuantumRegister(117, 'ancilla'), 26): 30, Qubit(QuantumRegister(117, 'ancilla'), 27): 31, Qubit(QuantumRegister(117, 'ancilla'), 28): 32, Qubit(QuantumRegister(117, 'ancilla'), 29): 33, Qubit(QuantumRegister(117, 'ancilla'), 30): 34, Qubit(QuantumRegister(117, 'ancilla'), 31): 35, Qubit(QuantumRegister(117, 'ancilla'), 32): 37, Qubit(QuantumRegister(117, 'ancilla'), 33): 38, Qubit(QuantumRegister(117, 'ancilla'), 34): 39, Qubit(QuantumRegister(117, 'ancilla'), 35): 40, Qubit(QuantumRegister(117, 'ancilla'), 36): 41, Qubit(QuantumRegister(117, 'ancilla'), 37): 42, Qubit(QuantumRegister(117, 'ancilla'), 38): 43, Qubit(QuantumRegister(117, 'ancilla'), 39): 44, Qubit(QuantumRegister(117, 'ancilla'), 40): 45, Qubit(QuantumRegister(117, 'ancilla'), 41): 46, Qubit(QuantumRegister(117, 'ancilla'), 42): 47, Qubit(QuantumRegister(117, 'ancilla'), 43): 48, Qubit(QuantumRegister(117, 'ancilla'), 44): 49, Qubit(QuantumRegister(117, 'ancilla'), 45): 50, Qubit(QuantumRegister(117, 'ancilla'), 46): 52, Qubit(QuantumRegister(117, 'ancilla'), 47): 53, Qubit(QuantumRegister(117, 'ancilla'), 48): 54, Qubit(QuantumRegister(117, 'ancilla'), 49): 55, Qubit(QuantumRegister(117, 'ancilla'), 50): 56, Qubit(QuantumRegister(117, 'ancilla'), 51): 57, Qubit(QuantumRegister(117, 'ancilla'), 52): 58, Qubit(QuantumRegister(117, 'ancilla'), 53): 59, Qubit(QuantumRegister(117, 'ancilla'), 54): 60, Qubit(QuantumRegister(117, 'ancilla'), 55): 61, Qubit(QuantumRegister(117, 'ancilla'), 56): 62, Qubit(QuantumRegister(117, 'ancilla'), 57): 63, Qubit(QuantumRegister(117, 'ancilla'), 58): 64, Qubit(QuantumRegister(117, 'ancilla'), 59): 65, Qubit(QuantumRegister(117, 'ancilla'), 60): 66, Qubit(QuantumRegister(117, 'ancilla'), 61): 67, Qubit(QuantumRegister(117, 'ancilla'), 62): 68, Qubit(QuantumRegister(117, 'ancilla'), 63): 69, Qubit(QuantumRegister(117, 'ancilla'), 64): 70, Qubit(QuantumRegister(117, 'ancilla'), 65): 71, Qubit(QuantumRegister(117, 'ancilla'), 66): 72, Qubit(QuantumRegister(117, 'ancilla'), 67): 73, Qubit(QuantumRegister(117, 'ancilla'), 68): 74, Qubit(QuantumRegister(117, 'ancilla'), 69): 75, Qubit(QuantumRegister(117, 'ancilla'), 70): 76, Qubit(QuantumRegister(117, 'ancilla'), 71): 77, Qubit(QuantumRegister(117, 'ancilla'), 72): 78, Qubit(QuantumRegister(117, 'ancilla'), 73): 79, Qubit(QuantumRegister(117, 'ancilla'), 74): 80, Qubit(QuantumRe ...
# [36, 2, 116, 111, 110, 51, 17, 125, 20, 11]

# %%
sampler = SamplerV2(backend=backend)
shots = 100
# job = sampler.run(circuits, shots=shots)
# 'cxsk1rqy1ae0008n4420' t_array = t_array = [0, 40_000, 80_000, 120_000, 160_000, 200_000, 240_000, 280_000, 320_000, 360_000, 400_000, 440_000, 480_000, 520_000, 560_000, 600_000, 640_000, 680_000, 720_000, 760_000, 800_000]
# 'cxsk7v70v1500080c02g' t_array = [t*5_000 for t in range(0, 81)]
# 'cxskbbd3wrp0008kqh70' t_array = [t*5_000 for t in range(0, 161)]
# job = service.job('cxskn4m0v1500080c0a0') # t_array = [t*5_000 for t in range(0, 81)]
job = service.job('cxy8afs0v1500080phj0') # HS-SdgH t_array = [t*5_000 for t in range(0, 81)]
pub_result = job.result()

# %%
import numpy as np

# print("error rate:")

results = []

for i in range(len(t_array)):
    result = pub_result[i]
    meas = result['__value__']['data']['c'].get_counts()
    
    qubit_results = {}

    # print(f"@ {t_array[i]*dt/1000}us")

    for q in range(10):
        qubit_results[q] = {
            '0': np.sum([meas[r] for r in meas if r[9-q] == '0']),
            '1': np.sum([meas[r] for r in meas if r[9-q] == '1']),
        }

    # print(*[f"\t {round(qubit_results[q]['0'])}%" for q in range(10)])

    results.append(qubit_results)

    # print(qubit_results)

# %%
import matplotlib.pyplot as plt
import math

# Example data arrays
x = [t*dt/1000 for t in t_array]
y = [[(r[q]['0']) for r in results] for q in range(10)]

# plt.axhline(y=-1, color='r', linestyle='--')

# Create the plot
# for q in range(10):
for q in range(10):
    plt.plot(x, y[q])

    # Add labels and title
    plt.xlabel('time (μs)')
    plt.ylabel('fidelity (%)')
    plt.title(f'qubit: {best_T2_qubits[q].Qubit}')
    # plt.legend()

    # Display the plot
    plt.show()

# %%
from scipy.optimize import curve_fit

# Definir la función modelo
def model_exp_cos(t, T2, w):
    return 50 * (1 + np.exp(-t/T2) * np.cos(w * t) )

# Datos de ejemplo (t y y)
t_data = np.array(x)  # Valores de t

for q in range(10):

    y_data = np.array(y[q])  # Valores de y

    # Ajustar la curva a los datos
    try:
        params, covariance = curve_fit(model_exp_cos, t_data, y_data, p0=[1, 1])
    except:
        print(f"Error ajustando los datos para qubit {q}")
        continue

    # Parámetros ajustados
    T2_estimated, w_estimated = params
    w_estimated *= 1000
    print(f"Parámetro T2 estimado: {round(T2_estimated,2)} μs")
    print(f"Parámetro ω estimado: {round(w_estimated,2)} kHz")
    print(f"T2 real: {round(best_T2_qubits[q].T2,2)} μs")

    y_results = [model_exp_cos(t, *params) for t in t_data]

    plt.plot(t_data, y_data, 'b.')
    plt.plot(t_data, y_results, 'r-', label='fit: \nT2=%5.2fμs\n w=%5.2fkHz' % (T2_estimated, w_estimated))
    plt.xlabel('time (μs)')
    plt.ylabel('fidelity (%)')
    plt.title(f'qubit: {best_T2_qubits[q].Qubit}')
    plt.legend()

    # Display the plot
    plt.show()
# Out:
# Parámetro T2 estimado: 4.71 μs
# Parámetro ω estimado: -54.55 kHz
# T2 real: 326.49 μs
# Parámetro T2 estimado: 38.63 μs
# Parámetro ω estimado: 181.29 kHz
# T2 real: 310.76 μs
# Error ajustando los datos para qubit 2
# Error ajustando los datos para qubit 3
# Parámetro T2 estimado: 57.17 μs
# Parámetro ω estimado: 104.71 kHz
# T2 real: 286.38 μs
# Parámetro T2 estimado: 21.75 μs
# Parámetro ω estimado: 281.7 kHz
# T2 real: 278.68 μs
# Parámetro T2 estimado: 61.91 μs
# Parámetro ω estimado: 35.24 kHz
# T2 real: 274.75 μs
# Parámetro T2 estimado: 116.36 μs
# Parámetro ω estimado: 68.87 kHz
# T2 real: 257.99 μs
# Error ajustando los datos para qubit 8
# Error ajustando los datos para qubit 9
